# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!git clone https://github.com/kbardool/keras-frcnn.git

# %%
#!git clone https://github.com/Shenggan/BCCD_Dataset.git

# %%
# !pip uninstall Keras
# Out:
# Uninstalling Keras-2.2.5:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/Keras-2.2.5.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/docs/*
#     /usr/local/lib/python3.6/dist-packages/keras/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.6/dist-packages/docs/md_autogen.py
#     /usr/local/lib/python3.6/dist-packages/docs/update_docs.py
# Proceed (y/n)? y
#   Successfully uninstalled Keras-2.2.5

# %%
# !pip uninstall tensorflow
# Out:
# Uninstalling tensorflow-2.2.0rc2:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.2.0rc2.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.2.0rc2

# %%
# !pip install tensorflow-gpu==1.15
# Out:
# Collecting tensorflow-gpu==1.15
#   Downloading https://files.pythonhosted.org/packages/a5/ad/933140e74973fb917a194ab814785e7c23680ca5dee6d663a509fe9579b6/tensorflow_gpu-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (411.5MB)
#      |████████████████████████████████| 411.5MB 43kB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (3.2.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.0.8)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.12.1)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 51.5MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (3.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.1.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 47.8MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.34.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.8.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.27.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.18.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.12.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.15) (46.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15) (3.2.1)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=8ff5dde0db8197abfeb4d5f414ce4a75e871a43bbeefe1c34cb5ba2a902a81fb
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# Installing collected packages: gast, tensorflow-estimator, tensorboard, tensorflow-gpu
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
# Successfully installed gast-0.2.2 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.0

# %%
# !pip install tensorflow==1.15
# Out:
# Collecting tensorflow==1.15
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 15kB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.9.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.15.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.34.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.2.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.2)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.27.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.18.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.10.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.2.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (46.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# ERROR: fancyimpute 0.4.3 requires keras>=2.0.0, which is not installed.
# Installing collected packages: tensorflow
# Successfully installed tensorflow-1.15.0

# %%
# !pip install Keras==2.0.3
# Out:
# Collecting Keras==2.0.3
#   Downloading https://files.pythonhosted.org/packages/1b/36/fc4b247ec139ad9cc6f223ed10729d85401fc5203703c23457794f9bfe60/Keras-2.0.3.tar.gz (196kB)
#      |████████████████████████████████| 204kB 12.5MB/s
# Requirement already satisfied: theano in /usr/local/lib/python3.6/dist-packages (from Keras==2.0.3) (1.0.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras==2.0.3) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from Keras==2.0.3) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from theano->Keras==2.0.3) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from theano->Keras==2.0.3) (1.18.2)
# Building wheels for collected packages: Keras
#   Building wheel for Keras (setup.py) ... done
#   Created wheel for Keras: filename=Keras-2.0.3-cp36-none-any.whl size=232962 sha256=31dc7e43828f6589be01919eb618491fab4f270b30e5a02ae24c1258449d5106
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built Keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# Installing collected packages: Keras
# Successfully installed Keras-2.0.3

# %%
cd /content/drive/My\ Drive/Colab\ Notebooks/keras-frcnn
# Out:
# /content/drive/My Drive/Colab Notebooks/keras-frcnn

# %%
# !python train_frcnn.py -o simple -p train_annotate9.txt
# Out:
# Streaming output truncated to the last 5000 lines.
#  592/1000 [================>.............] - ETA: 1274s - rpn_cls: 0.0208 - rpn_regr: 0.0639 - detector_cls: 0.0595 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  595/1000 [================>.............] - ETA: 1264s - rpn_cls: 0.0207 - rpn_regr: 0.0639 - detector_cls: 0.0596 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  596/1000 [================>.............] - ETA: 1261s - rpn_cls: 0.0207 - rpn_regr: 0.0639 - detector_cls: 0.0597 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  600/1000 [=================>............] - ETA: 1246s - rpn_cls: 0.0206 - rpn_regr: 0.0642 - detector_cls: 0.0604 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  605/1000 [=================>............] - ETA: 1227s - rpn_cls: 0.0205 - rpn_regr: 0.0647 - detector_cls: 0.0608 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  607/1000 [=================>............] - ETA: 1222s - rpn_cls: 0.0204 - rpn_regr: 0.0649 - detector_cls: 0.0609 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  609/1000 [=================>............] - ETA: 1216s - rpn_cls: 0.0205 - rpn_regr: 0.0648 - detector_cls: 0.0614 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
#  610/1000 [=================>............] - ETA: 1212s - rpn_cls: 0.0204 - rpn_regr: 0.0648 - detector_cls: 0.0616 - detector_regr: 0.0250Exception: 'a' cannot be empty unless no samples are taken
#  614/1000 [=================>............] - ETA: 1197s - rpn_cls: 0.0203 - rpn_regr: 0.0651 - detector_cls: 0.0613 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  616/1000 [=================>............] - ETA: 1191s - rpn_cls: 0.0202 - rpn_regr: 0.0657 - detector_cls: 0.0613 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  618/1000 [=================>............] - ETA: 1185s - rpn_cls: 0.0202 - rpn_regr: 0.0657 - detector_cls: 0.0612 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  619/1000 [=================>............] - ETA: 1182s - rpn_cls: 0.0202 - rpn_regr: 0.0659 - detector_cls: 0.0611 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  622/1000 [=================>............] - ETA: 1175s - rpn_cls: 0.0201 - rpn_regr: 0.0665 - detector_cls: 0.0610 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
#  630/1000 [=================>............] - ETA: 1147s - rpn_cls: 0.0205 - rpn_regr: 0.0666 - detector_cls: 0.0611 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  633/1000 [=================>............] - ETA: 1137s - rpn_cls: 0.0204 - rpn_regr: 0.0667 - detector_cls: 0.0610 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
#  635/1000 [==================>...........] - ETA: 1130s - rpn_cls: 0.0204 - rpn_regr: 0.0668 - detector_cls: 0.0616 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  638/1000 [==================>...........] - ETA: 1120s - rpn_cls: 0.0203 - rpn_regr: 0.0668 - detector_cls: 0.0618 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  639/1000 [==================>...........] - ETA: 1117s - rpn_cls: 0.0202 - rpn_regr: 0.0668 - detector_cls: 0.0617 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  644/1000 [==================>...........] - ETA: 1098s - rpn_cls: 0.0201 - rpn_regr: 0.0670 - detector_cls: 0.0615 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  645/1000 [==================>...........] - ETA: 1098s - rpn_cls: 0.0201 - rpn_regr: 0.0669 - detector_cls: 0.0616 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  647/1000 [==================>...........] - ETA: 1091s - rpn_cls: 0.0203 - rpn_regr: 0.0668 - detector_cls: 0.0614 - detector_regr: 0.0247Average number of overlapping bounding boxes from RPN = 1.058 for 1000 previous iterations
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  648/1000 [==================>...........] - ETA: 1089s - rpn_cls: 0.0203 - rpn_regr: 0.0668 - detector_cls: 0.0614 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  649/1000 [==================>...........] - ETA: 1087s - rpn_cls: 0.0204 - rpn_regr: 0.0667 - detector_cls: 0.0613 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
#  652/1000 [==================>...........] - ETA: 1077s - rpn_cls: 0.0203 - rpn_regr: 0.0668 - detector_cls: 0.0611 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
#  654/1000 [==================>...........] - ETA: 1070s - rpn_cls: 0.0202 - rpn_regr: 0.0667 - detector_cls: 0.0614 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  656/1000 [==================>...........] - ETA: 1064s - rpn_cls: 0.0202 - rpn_regr: 0.0666 - detector_cls: 0.0613 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  659/1000 [==================>...........] - ETA: 1054s - rpn_cls: 0.0201 - rpn_regr: 0.0670 - detector_cls: 0.0614 - detector_regr: 0.0251Exception: 'a' cannot be empty unless no samples are taken
#  663/1000 [==================>...........] - ETA: 1040s - rpn_cls: 0.0201 - rpn_regr: 0.0669 - detector_cls: 0.0614 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  667/1000 [===================>..........] - ETA: 1026s - rpn_cls: 0.0203 - rpn_regr: 0.0668 - detector_cls: 0.0611 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  668/1000 [===================>..........] - ETA: 1023s - rpn_cls: 0.0203 - rpn_regr: 0.0669 - detector_cls: 0.0611 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  670/1000 [===================>..........] - ETA: 1016s - rpn_cls: 0.0203 - rpn_regr: 0.0668 - detector_cls: 0.0609 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  671/1000 [===================>..........] - ETA: 1013s - rpn_cls: 0.0202 - rpn_regr: 0.0668 - detector_cls: 0.0608 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  673/1000 [===================>..........] - ETA: 1010s - rpn_cls: 0.0202 - rpn_regr: 0.0667 - detector_cls: 0.0610 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  674/1000 [===================>..........] - ETA: 1007s - rpn_cls: 0.0202 - rpn_regr: 0.0668 - detector_cls: 0.0609 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  675/1000 [===================>..........] - ETA: 1007s - rpn_cls: 0.0201 - rpn_regr: 0.0667 - detector_cls: 0.0613 - detector_regr: 0.0252Exception: 'a' cannot be empty unless no samples are taken
#  678/1000 [===================>..........] - ETA: 996s - rpn_cls: 0.0200 - rpn_regr: 0.0667 - detector_cls: 0.0611 - detector_regr: 0.0251Exception: 'a' cannot be empty unless no samples are taken
#  681/1000 [===================>..........] - ETA: 986s - rpn_cls: 0.0200 - rpn_regr: 0.0666 - detector_cls: 0.0614 - detector_regr: 0.0252Exception: 'a' cannot be empty unless no samples are taken
#  682/1000 [===================>..........] - ETA: 982s - rpn_cls: 0.0200 - rpn_regr: 0.0667 - detector_cls: 0.0613 - detector_regr: 0.0251Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  683/1000 [===================>..........] - ETA: 981s - rpn_cls: 0.0199 - rpn_regr: 0.0666 - detector_cls: 0.0614 - detector_regr: 0.0252Exception: 'a' cannot be empty unless no samples are taken
#  684/1000 [===================>..........] - ETA: 978s - rpn_cls: 0.0199 - rpn_regr: 0.0668 - detector_cls: 0.0614 - detector_regr: 0.0251Exception: 'a' cannot be empty unless no samples are taken
#  686/1000 [===================>..........] - ETA: 971s - rpn_cls: 0.0199 - rpn_regr: 0.0671 - detector_cls: 0.0613 - detector_regr: 0.0251Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  690/1000 [===================>..........] - ETA: 957s - rpn_cls: 0.0199 - rpn_regr: 0.0668 - detector_cls: 0.0612 - detector_regr: 0.0250Exception: 'a' cannot be empty unless no samples are taken
#  692/1000 [===================>..........] - ETA: 950s - rpn_cls: 0.0198 - rpn_regr: 0.0667 - detector_cls: 0.0612 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
#  695/1000 [===================>..........] - ETA: 941s - rpn_cls: 0.0199 - rpn_regr: 0.0667 - detector_cls: 0.0619 - detector_regr: 0.0250Exception: 'a' cannot be empty unless no samples are taken
#  699/1000 [===================>..........] - ETA: 927s - rpn_cls: 0.0198 - rpn_regr: 0.0666 - detector_cls: 0.0616 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
#  702/1000 [====================>.........] - ETA: 917s - rpn_cls: 0.0199 - rpn_regr: 0.0667 - detector_cls: 0.0614 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  703/1000 [====================>.........] - ETA: 914s - rpn_cls: 0.0199 - rpn_regr: 0.0666 - detector_cls: 0.0613 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  704/1000 [====================>.........] - ETA: 911s - rpn_cls: 0.0199 - rpn_regr: 0.0665 - detector_cls: 0.0612 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  705/1000 [====================>.........] - ETA: 910s - rpn_cls: 0.0199 - rpn_regr: 0.0665 - detector_cls: 0.0616 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  707/1000 [====================>.........] - ETA: 903s - rpn_cls: 0.0198 - rpn_regr: 0.0663 - detector_cls: 0.0624 - detector_regr: 0.0250Exception: 'a' cannot be empty unless no samples are taken
#  708/1000 [====================>.........] - ETA: 900s - rpn_cls: 0.0198 - rpn_regr: 0.0663 - detector_cls: 0.0623 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
#  709/1000 [====================>.........] - ETA: 897s - rpn_cls: 0.0198 - rpn_regr: 0.0662 - detector_cls: 0.0622 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  712/1000 [====================>.........] - ETA: 890s - rpn_cls: 0.0197 - rpn_regr: 0.0661 - detector_cls: 0.0623 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  713/1000 [====================>.........] - ETA: 888s - rpn_cls: 0.0197 - rpn_regr: 0.0663 - detector_cls: 0.0622 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  715/1000 [====================>.........] - ETA: 882s - rpn_cls: 0.0196 - rpn_regr: 0.0662 - detector_cls: 0.0622 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  718/1000 [====================>.........] - ETA: 872s - rpn_cls: 0.0196 - rpn_regr: 0.0663 - detector_cls: 0.0620 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  726/1000 [====================>.........] - ETA: 844s - rpn_cls: 0.0195 - rpn_regr: 0.0670 - detector_cls: 0.0621 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
#  730/1000 [====================>.........] - ETA: 830s - rpn_cls: 0.0194 - rpn_regr: 0.0668 - detector_cls: 0.0621 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  731/1000 [====================>.........] - ETA: 829s - rpn_cls: 0.0194 - rpn_regr: 0.0667 - detector_cls: 0.0621 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
#  735/1000 [=====================>........] - ETA: 815s - rpn_cls: 0.0194 - rpn_regr: 0.0667 - detector_cls: 0.0621 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  737/1000 [=====================>........] - ETA: 809s - rpn_cls: 0.0194 - rpn_regr: 0.0667 - detector_cls: 0.0620 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
#  741/1000 [=====================>........] - ETA: 795s - rpn_cls: 0.0193 - rpn_regr: 0.0665 - detector_cls: 0.0619 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
#  742/1000 [=====================>........] - ETA: 792s - rpn_cls: 0.0193 - rpn_regr: 0.0665 - detector_cls: 0.0618 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  744/1000 [=====================>........] - ETA: 787s - rpn_cls: 0.0196 - rpn_regr: 0.0666 - detector_cls: 0.0617 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  747/1000 [=====================>........] - ETA: 777s - rpn_cls: 0.0196 - rpn_regr: 0.0667 - detector_cls: 0.0616 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  748/1000 [=====================>........] - ETA: 775s - rpn_cls: 0.0195 - rpn_regr: 0.0667 - detector_cls: 0.0616 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  752/1000 [=====================>........] - ETA: 761s - rpn_cls: 0.0195 - rpn_regr: 0.0669 - detector_cls: 0.0619 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  753/1000 [=====================>........] - ETA: 759s - rpn_cls: 0.0195 - rpn_regr: 0.0669 - detector_cls: 0.0619 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  754/1000 [=====================>........] - ETA: 758s - rpn_cls: 0.0195 - rpn_regr: 0.0670 - detector_cls: 0.0618 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  755/1000 [=====================>........] - ETA: 755s - rpn_cls: 0.0195 - rpn_regr: 0.0669 - detector_cls: 0.0617 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  760/1000 [=====================>........] - ETA: 740s - rpn_cls: 0.0198 - rpn_regr: 0.0670 - detector_cls: 0.0617 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
#  767/1000 [======================>.......] - ETA: 715s - rpn_cls: 0.0196 - rpn_regr: 0.0668 - detector_cls: 0.0615 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
#  770/1000 [======================>.......] - ETA: 705s - rpn_cls: 0.0197 - rpn_regr: 0.0669 - detector_cls: 0.0617 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  773/1000 [======================>.......] - ETA: 696s - rpn_cls: 0.0196 - rpn_regr: 0.0669 - detector_cls: 0.0618 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  784/1000 [======================>.......] - ETA: 660s - rpn_cls: 0.0194 - rpn_regr: 0.0665 - detector_cls: 0.0618 - detector_regr: 0.0249Exception: 'a' cannot be empty unless no samples are taken
#  786/1000 [======================>.......] - ETA: 654s - rpn_cls: 0.0193 - rpn_regr: 0.0665 - detector_cls: 0.0617 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  788/1000 [======================>.......] - ETA: 647s - rpn_cls: 0.0193 - rpn_regr: 0.0664 - detector_cls: 0.0615 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  789/1000 [======================>.......] - ETA: 644s - rpn_cls: 0.0192 - rpn_regr: 0.0664 - detector_cls: 0.0615 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
#  793/1000 [======================>.......] - ETA: 631s - rpn_cls: 0.0192 - rpn_regr: 0.0661 - detector_cls: 0.0613 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  794/1000 [======================>.......] - ETA: 628s - rpn_cls: 0.0191 - rpn_regr: 0.0661 - detector_cls: 0.0612 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  795/1000 [======================>.......] - ETA: 625s - rpn_cls: 0.0191 - rpn_regr: 0.0660 - detector_cls: 0.0612 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  796/1000 [======================>.......] - ETA: 623s - rpn_cls: 0.0191 - rpn_regr: 0.0659 - detector_cls: 0.0611 - detector_regr: 0.0248Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  798/1000 [======================>.......] - ETA: 618s - rpn_cls: 0.0191 - rpn_regr: 0.0660 - detector_cls: 0.0612 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  799/1000 [======================>.......] - ETA: 617s - rpn_cls: 0.0191 - rpn_regr: 0.0661 - detector_cls: 0.0613 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  800/1000 [=======================>......] - ETA: 613s - rpn_cls: 0.0191 - rpn_regr: 0.0661 - detector_cls: 0.0613 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  804/1000 [=======================>......] - ETA: 601s - rpn_cls: 0.0190 - rpn_regr: 0.0660 - detector_cls: 0.0614 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  805/1000 [=======================>......] - ETA: 598s - rpn_cls: 0.0190 - rpn_regr: 0.0661 - detector_cls: 0.0614 - detector_regr: 0.0247Exception: 'a' cannot be empty unless no samples are taken
#  808/1000 [=======================>......] - ETA: 589s - rpn_cls: 0.0189 - rpn_regr: 0.0661 - detector_cls: 0.0613 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  809/1000 [=======================>......] - ETA: 586s - rpn_cls: 0.0189 - rpn_regr: 0.0660 - detector_cls: 0.0613 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
#  811/1000 [=======================>......] - ETA: 580s - rpn_cls: 0.0190 - rpn_regr: 0.0662 - detector_cls: 0.0616 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  813/1000 [=======================>......] - ETA: 574s - rpn_cls: 0.0189 - rpn_regr: 0.0661 - detector_cls: 0.0615 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
#  815/1000 [=======================>......] - ETA: 568s - rpn_cls: 0.0189 - rpn_regr: 0.0661 - detector_cls: 0.0614 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  816/1000 [=======================>......] - ETA: 565s - rpn_cls: 0.0189 - rpn_regr: 0.0660 - detector_cls: 0.0613 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  818/1000 [=======================>......] - ETA: 559s - rpn_cls: 0.0188 - rpn_regr: 0.0661 - detector_cls: 0.0616 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  819/1000 [=======================>......] - ETA: 557s - rpn_cls: 0.0188 - rpn_regr: 0.0660 - detector_cls: 0.0615 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
#  821/1000 [=======================>......] - ETA: 550s - rpn_cls: 0.0188 - rpn_regr: 0.0660 - detector_cls: 0.0616 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
#  822/1000 [=======================>......] - ETA: 547s - rpn_cls: 0.0187 - rpn_regr: 0.0660 - detector_cls: 0.0616 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  826/1000 [=======================>......] - ETA: 535s - rpn_cls: 0.0187 - rpn_regr: 0.0657 - detector_cls: 0.0613 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
#  828/1000 [=======================>......] - ETA: 528s - rpn_cls: 0.0186 - rpn_regr: 0.0656 - detector_cls: 0.0620 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  830/1000 [=======================>......] - ETA: 522s - rpn_cls: 0.0186 - rpn_regr: 0.0656 - detector_cls: 0.0620 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
#  833/1000 [=======================>......] - ETA: 512s - rpn_cls: 0.0185 - rpn_regr: 0.0654 - detector_cls: 0.0618 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  837/1000 [========================>.....] - ETA: 501s - rpn_cls: 0.0185 - rpn_regr: 0.0652 - detector_cls: 0.0616 - detector_regr: 0.0243Exception: 'a' cannot be empty unless no samples are taken
#  840/1000 [========================>.....] - ETA: 492s - rpn_cls: 0.0185 - rpn_regr: 0.0652 - detector_cls: 0.0619 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
#  842/1000 [========================>.....] - ETA: 485s - rpn_cls: 0.0184 - rpn_regr: 0.0651 - detector_cls: 0.0623 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  843/1000 [========================>.....] - ETA: 483s - rpn_cls: 0.0184 - rpn_regr: 0.0651 - detector_cls: 0.0623 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  846/1000 [========================>.....] - ETA: 473s - rpn_cls: 0.0184 - rpn_regr: 0.0650 - detector_cls: 0.0621 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  847/1000 [========================>.....] - ETA: 471s - rpn_cls: 0.0183 - rpn_regr: 0.0649 - detector_cls: 0.0621 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
#  848/1000 [========================>.....] - ETA: 468s - rpn_cls: 0.0183 - rpn_regr: 0.0649 - detector_cls: 0.0620 - detector_regr: 0.0243Exception: 'a' cannot be empty unless no samples are taken
#  850/1000 [========================>.....] - ETA: 461s - rpn_cls: 0.0183 - rpn_regr: 0.0648 - detector_cls: 0.0619 - detector_regr: 0.0243Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  851/1000 [========================>.....] - ETA: 458s - rpn_cls: 0.0183 - rpn_regr: 0.0648 - detector_cls: 0.0618 - detector_regr: 0.0243Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  853/1000 [========================>.....] - ETA: 453s - rpn_cls: 0.0183 - rpn_regr: 0.0648 - detector_cls: 0.0620 - detector_regr: 0.0243Exception: 'a' cannot be empty unless no samples are taken
#  854/1000 [========================>.....] - ETA: 450s - rpn_cls: 0.0183 - rpn_regr: 0.0647 - detector_cls: 0.0620 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  856/1000 [========================>.....] - ETA: 444s - rpn_cls: 0.0183 - rpn_regr: 0.0648 - detector_cls: 0.0619 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
#  857/1000 [========================>.....] - ETA: 442s - rpn_cls: 0.0182 - rpn_regr: 0.0647 - detector_cls: 0.0618 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  860/1000 [========================>.....] - ETA: 432s - rpn_cls: 0.0185 - rpn_regr: 0.0647 - detector_cls: 0.0620 - detector_regr: 0.0246Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  862/1000 [========================>.....] - ETA: 426s - rpn_cls: 0.0185 - rpn_regr: 0.0646 - detector_cls: 0.0620 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
#  864/1000 [========================>.....] - ETA: 419s - rpn_cls: 0.0186 - rpn_regr: 0.0647 - detector_cls: 0.0618 - detector_regr: 0.0245Exception: 'a' cannot be empty unless no samples are taken
#  866/1000 [========================>.....] - ETA: 413s - rpn_cls: 0.0186 - rpn_regr: 0.0647 - detector_cls: 0.0617 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
#  867/1000 [=========================>....] - ETA: 410s - rpn_cls: 0.0186 - rpn_regr: 0.0646 - detector_cls: 0.0616 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
#  869/1000 [=========================>....] - ETA: 403s - rpn_cls: 0.0185 - rpn_regr: 0.0647 - detector_cls: 0.0619 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  870/1000 [=========================>....] - ETA: 401s - rpn_cls: 0.0185 - rpn_regr: 0.0647 - detector_cls: 0.0618 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
#  877/1000 [=========================>....] - ETA: 378s - rpn_cls: 0.0188 - rpn_regr: 0.0646 - detector_cls: 0.0617 - detector_regr: 0.0244Exception: 'a' cannot be empty unless no samples are taken
#  879/1000 [=========================>....] - ETA: 372s - rpn_cls: 0.0188 - rpn_regr: 0.0645 - detector_cls: 0.0617 - detector_regr: 0.0243Exception: 'a' cannot be empty unless no samples are taken
#  880/1000 [=========================>....] - ETA: 369s - rpn_cls: 0.0187 - rpn_regr: 0.0645 - detector_cls: 0.0617 - detector_regr: 0.0243Exception: 'a' cannot be empty unless no samples are taken
#  882/1000 [=========================>....] - ETA: 362s - rpn_cls: 0.0187 - rpn_regr: 0.0644 - detector_cls: 0.0617 - detector_regr: 0.0243Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  883/1000 [=========================>....] - ETA: 359s - rpn_cls: 0.0187 - rpn_regr: 0.0644 - detector_cls: 0.0617 - detector_regr: 0.0243Exception: 'a' cannot be empty unless no samples are taken
#  884/1000 [=========================>....] - ETA: 356s - rpn_cls: 0.0187 - rpn_regr: 0.0643 - detector_cls: 0.0616 - detector_regr: 0.0242Exception: 'a' cannot be empty unless no samples are taken
#  885/1000 [=========================>....] - ETA: 353s - rpn_cls: 0.0187 - rpn_regr: 0.0643 - detector_cls: 0.0617 - detector_regr: 0.0242Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  887/1000 [=========================>....] - ETA: 347s - rpn_cls: 0.0186 - rpn_regr: 0.0642 - detector_cls: 0.0619 - detector_regr: 0.0242Exception: 'a' cannot be empty unless no samples are taken
#  888/1000 [=========================>....] - ETA: 345s - rpn_cls: 0.0186 - rpn_regr: 0.0642 - detector_cls: 0.0619 - detector_regr: 0.0241Exception: 'a' cannot be empty unless no samples are taken
#  891/1000 [=========================>....] - ETA: 335s - rpn_cls: 0.0187 - rpn_regr: 0.0641 - detector_cls: 0.0618 - detector_regr: 0.0241Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  892/1000 [=========================>....] - ETA: 332s - rpn_cls: 0.0187 - rpn_regr: 0.0641 - detector_cls: 0.0621 - detector_regr: 0.0241Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  893/1000 [=========================>....] - ETA: 329s - rpn_cls: 0.0187 - rpn_regr: 0.0640 - detector_cls: 0.0621 - detector_regr: 0.0241Exception: 'a' cannot be empty unless no samples are taken
#  894/1000 [=========================>....] - ETA: 326s - rpn_cls: 0.0187 - rpn_regr: 0.0640 - detector_cls: 0.0620 - detector_regr: 0.0241Exception: 'a' cannot be empty unless no samples are taken
#  895/1000 [=========================>....] - ETA: 323s - rpn_cls: 0.0187 - rpn_regr: 0.0640 - detector_cls: 0.0620 - detector_regr: 0.0241Exception: 'a' cannot be empty unless no samples are taken
#  897/1000 [=========================>....] - ETA: 317s - rpn_cls: 0.0186 - rpn_regr: 0.0639 - detector_cls: 0.0619 - detector_regr: 0.0240Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  898/1000 [=========================>....] - ETA: 314s - rpn_cls: 0.0186 - rpn_regr: 0.0640 - detector_cls: 0.0619 - detector_regr: 0.0240Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  900/1000 [==========================>...] - ETA: 308s - rpn_cls: 0.0188 - rpn_regr: 0.0640 - detector_cls: 0.0619 - detector_regr: 0.0241Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  902/1000 [==========================>...] - ETA: 302s - rpn_cls: 0.0187 - rpn_regr: 0.0639 - detector_cls: 0.0618 - detector_regr: 0.0241Exception: 'a' cannot be empty unless no samples are taken
#  904/1000 [==========================>...] - ETA: 296s - rpn_cls: 0.0187 - rpn_regr: 0.0638 - detector_cls: 0.0618 - detector_regr: 0.0241Exception: 'a' cannot be empty unless no samples are taken
#  907/1000 [==========================>...] - ETA: 287s - rpn_cls: 0.0186 - rpn_regr: 0.0638 - detector_cls: 0.0619 - detector_regr: 0.0240Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  910/1000 [==========================>...] - ETA: 277s - rpn_cls: 0.0186 - rpn_regr: 0.0638 - detector_cls: 0.0619 - detector_regr: 0.0240Exception: 'a' cannot be empty unless no samples are taken
#  913/1000 [==========================>...] - ETA: 268s - rpn_cls: 0.0185 - rpn_regr: 0.0636 - detector_cls: 0.0617 - detector_regr: 0.0239Exception: 'a' cannot be empty unless no samples are taken
#  914/1000 [==========================>...] - ETA: 265s - rpn_cls: 0.0185 - rpn_regr: 0.0637 - detector_cls: 0.0618 - detector_regr: 0.0239Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  915/1000 [==========================>...] - ETA: 262s - rpn_cls: 0.0191 - rpn_regr: 0.0637 - detector_cls: 0.0618 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
#  917/1000 [==========================>...] - ETA: 255s - rpn_cls: 0.0196 - rpn_regr: 0.0637 - detector_cls: 0.0617 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  924/1000 [==========================>...] - ETA: 233s - rpn_cls: 0.0195 - rpn_regr: 0.0636 - detector_cls: 0.0616 - detector_regr: 0.0239Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  929/1000 [==========================>...] - ETA: 218s - rpn_cls: 0.0194 - rpn_regr: 0.0636 - detector_cls: 0.0615 - detector_regr: 0.0237Exception: 'a' cannot be empty unless no samples are taken
#  931/1000 [==========================>...] - ETA: 212s - rpn_cls: 0.0195 - rpn_regr: 0.0636 - detector_cls: 0.0614 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
#  935/1000 [===========================>..] - ETA: 199s - rpn_cls: 0.0195 - rpn_regr: 0.0636 - detector_cls: 0.0613 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  939/1000 [===========================>..] - ETA: 187s - rpn_cls: 0.0195 - rpn_regr: 0.0636 - detector_cls: 0.0613 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
#  940/1000 [===========================>..] - ETA: 184s - rpn_cls: 0.0195 - rpn_regr: 0.0636 - detector_cls: 0.0612 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
#  941/1000 [===========================>..] - ETA: 181s - rpn_cls: 0.0194 - rpn_regr: 0.0636 - detector_cls: 0.0613 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  945/1000 [===========================>..] - ETA: 169s - rpn_cls: 0.0194 - rpn_regr: 0.0635 - detector_cls: 0.0613 - detector_regr: 0.0239Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  946/1000 [===========================>..] - ETA: 166s - rpn_cls: 0.0194 - rpn_regr: 0.0635 - detector_cls: 0.0612 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  949/1000 [===========================>..] - ETA: 157s - rpn_cls: 0.0194 - rpn_regr: 0.0634 - detector_cls: 0.0611 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  951/1000 [===========================>..] - ETA: 150s - rpn_cls: 0.0193 - rpn_regr: 0.0633 - detector_cls: 0.0611 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  958/1000 [===========================>..] - ETA: 129s - rpn_cls: 0.0193 - rpn_regr: 0.0631 - detector_cls: 0.0609 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  960/1000 [===========================>..] - ETA: 122s - rpn_cls: 0.0194 - rpn_regr: 0.0630 - detector_cls: 0.0608 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
#  963/1000 [===========================>..] - ETA: 113s - rpn_cls: 0.0193 - rpn_regr: 0.0629 - detector_cls: 0.0606 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  967/1000 [============================>.] - ETA: 101s - rpn_cls: 0.0192 - rpn_regr: 0.0628 - detector_cls: 0.0606 - detector_regr: 0.0237Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  968/1000 [============================>.] - ETA: 98s - rpn_cls: 0.0192 - rpn_regr: 0.0628 - detector_cls: 0.0605 - detector_regr: 0.0237 Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  970/1000 [============================>.] - ETA: 92s - rpn_cls: 0.0193 - rpn_regr: 0.0627 - detector_cls: 0.0606 - detector_regr: 0.0238Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  973/1000 [============================>.] - ETA: 83s - rpn_cls: 0.0192 - rpn_regr: 0.0626 - detector_cls: 0.0605 - detector_regr: 0.0237Exception: 'a' cannot be empty unless no samples are taken
#  977/1000 [============================>.] - ETA: 70s - rpn_cls: 0.0192 - rpn_regr: 0.0628 - detector_cls: 0.0606 - detector_regr: 0.0237Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  980/1000 [============================>.] - ETA: 61s - rpn_cls: 0.0191 - rpn_regr: 0.0627 - detector_cls: 0.0605 - detector_regr: 0.0237Exception: 'a' cannot be empty unless no samples are taken
#  983/1000 [============================>.] - ETA: 52s - rpn_cls: 0.0191 - rpn_regr: 0.0626 - detector_cls: 0.0606 - detector_regr: 0.0237Exception: 'a' cannot be empty unless no samples are taken
#  984/1000 [============================>.] - ETA: 49s - rpn_cls: 0.0191 - rpn_regr: 0.0626 - detector_cls: 0.0605 - detector_regr: 0.0237Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  985/1000 [============================>.] - ETA: 46s - rpn_cls: 0.0191 - rpn_regr: 0.0625 - detector_cls: 0.0606 - detector_regr: 0.0237Exception: 'a' cannot be empty unless no samples are taken
#  986/1000 [============================>.] - ETA: 43s - rpn_cls: 0.0190 - rpn_regr: 0.0625 - detector_cls: 0.0605 - detector_regr: 0.0237Exception: 'a' cannot be empty unless no samples are taken
#  988/1000 [============================>.] - ETA: 37s - rpn_cls: 0.0190 - rpn_regr: 0.0624 - detector_cls: 0.0604 - detector_regr: 0.0236Exception: 'a' cannot be empty unless no samples are taken
#  991/1000 [============================>.] - ETA: 27s - rpn_cls: 0.0191 - rpn_regr: 0.0625 - detector_cls: 0.0602 - detector_regr: 0.0236Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  994/1000 [============================>.] - ETA: 18s - rpn_cls: 0.0191 - rpn_regr: 0.0624 - detector_cls: 0.0601 - detector_regr: 0.0235Exception: 'a' cannot be empty unless no samples are taken
#  999/1000 [============================>.] - ETA: 3s - rpn_cls: 0.0190 - rpn_regr: 0.0622 - detector_cls: 0.0600 - detector_regr: 0.0235Exception: 'a' cannot be empty unless no samples are taken
# 1000/1000 [==============================] - 3081s - rpn_cls: 0.0190 - rpn_regr: 0.0621 - detector_cls: 0.0599 - detector_regr: 0.0235
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 1.089533932951758
# Classifier accuracy for bounding boxes from RPN: 0.98340625
# Loss RPN classifier: 0.018981381669175432
# Loss RPN regression: 0.06213747150154086
# Loss Detector classifier: 0.05991324983838209
# Loss Detector regression: 0.02345811821224197
# Elapsed time: 3082.994406938553
# Total loss decreased from 0.2264342095082742 to 0.16449022122134035, saving weights
# Epoch 6/50
# Exception: 'a' cannot be empty unless no samples are taken
#    4/1000 [..............................] - ETA: 2182s - rpn_cls: 0.0024 - rpn_regr: 0.0259 - detector_cls: 0.0117 - detector_regr: 0.0093Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#    5/1000 [..............................] - ETA: 3011s - rpn_cls: 0.0019 - rpn_regr: 0.0342 - detector_cls: 0.0094 - detector_regr: 0.0075Exception: 'a' cannot be empty unless no samples are taken
#    8/1000 [..............................] - ETA: 2605s - rpn_cls: 0.0021 - rpn_regr: 0.0338 - detector_cls: 0.0135 - detector_regr: 0.0069Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#   16/1000 [..............................] - ETA: 2275s - rpn_cls: 0.0119 - rpn_regr: 0.0336 - detector_cls: 0.0292 - detector_regr: 0.0056Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#   17/1000 [..............................] - ETA: 2722s - rpn_cls: 0.0112 - rpn_regr: 0.0327 - detector_cls: 0.0276 - detector_regr: 0.0053Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#   18/1000 [..............................] - ETA: 2876s - rpn_cls: 0.0106 - rpn_regr: 0.0326 - detector_cls: 0.0305 - detector_regr: 0.0063Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#   19/1000 [..............................] - ETA: 3042s - rpn_cls: 0.0102 - rpn_regr: 0.0317 - detector_cls: 0.0289 - detector_regr: 0.0059Exception: 'a' cannot be empty unless no samples are taken
#   20/1000 [..............................] - ETA: 2993s - rpn_cls: 0.0097 - rpn_regr: 0.0311 - detector_cls: 0.0284 - detector_regr: 0.0056Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#   21/1000 [..............................] - ETA: 3222s - rpn_cls: 0.0093 - rpn_regr: 0.0301 - detector_cls: 0.0273 - detector_regr: 0.0054Exception: 'a' cannot be empty unless no samples are taken
#   24/1000 [..............................] - ETA: 3223s - rpn_cls: 0.0083 - rpn_regr: 0.0291 - detector_cls: 0.0318 - detector_regr: 0.0065Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#   25/1000 [..............................] - ETA: 3346s - rpn_cls: 0.0080 - rpn_regr: 0.0288 - detector_cls: 0.0311 - detector_regr: 0.0097Exception: 'a' cannot be empty unless no samples are taken
#   28/1000 [..............................] - ETA: 3227s - rpn_cls: 0.0082 - rpn_regr: 0.0266 - detector_cls: 0.0278 - detector_regr: 0.0086Exception: 'a' cannot be empty unless no samples are taken
#   32/1000 [..............................] - ETA: 3025s - rpn_cls: 0.0268 - rpn_regr: 0.0292 - detector_cls: 0.0244 - detector_regr: 0.0083Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#   34/1000 [>.............................] - ETA: 3095s - rpn_cls: 0.0254 - rpn_regr: 0.0288 - detector_cls: 0.0277 - detector_regr: 0.0092Exception: 'a' cannot be empty unless no samples are taken
#   35/1000 [>.............................] - ETA: 3156s - rpn_cls: 0.0247 - rpn_regr: 0.0282 - detector_cls: 0.0325 - detector_regr: 0.0102Exception: 'a' cannot be empty unless no samples are taken
#   36/1000 [>.............................] - ETA: 3148s - rpn_cls: 0.0245 - rpn_regr: 0.0292 - detector_cls: 0.0362 - detector_regr: 0.0106Exception: 'a' cannot be empty unless no samples are taken
#   39/1000 [>.............................] - ETA: 3118s - rpn_cls: 0.0235 - rpn_regr: 0.0290 - detector_cls: 0.0354 - detector_regr: 0.0110Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#   40/1000 [>.............................] - ETA: 3113s - rpn_cls: 0.0230 - rpn_regr: 0.0286 - detector_cls: 0.0378 - detector_regr: 0.0107Exception: 'a' cannot be empty unless no samples are taken
#   43/1000 [>.............................] - ETA: 3038s - rpn_cls: 0.0289 - rpn_regr: 0.0291 - detector_cls: 0.0353 - detector_regr: 0.0101Exception: 'a' cannot be empty unless no samples are taken
#   44/1000 [>.............................] - ETA: 3031s - rpn_cls: 0.0283 - rpn_regr: 0.0287 - detector_cls: 0.0354 - detector_regr: 0.0100Exception: 'a' cannot be empty unless no samples are taken
#   46/1000 [>.............................] - ETA: 2971s - rpn_cls: 0.0271 - rpn_regr: 0.0289 - detector_cls: 0.0348 - detector_regr: 0.0097Exception: 'a' cannot be empty unless no samples are taken
#   48/1000 [>.............................] - ETA: 2926s - rpn_cls: 0.0260 - rpn_regr: 0.0292 - detector_cls: 0.0339 - detector_regr: 0.0096Exception: 'a' cannot be empty unless no samples are taken
# ...
# Exception: 'a' cannot be empty unless no samples are taken
#  165/1000 [===>..........................] - ETA: 2612s - rpn_cls: 0.0013 - rpn_regr: 0.0222 - detector_cls: 0.0027 - detector_regr: 0.0030Exception: 'a' cannot be empty unless no samples are taken
#  167/1000 [====>.........................] - ETA: 2602s - rpn_cls: 0.0013 - rpn_regr: 0.0222 - detector_cls: 0.0027 - detector_regr: 0.0029Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  168/1000 [====>.........................] - ETA: 2610s - rpn_cls: 0.0013 - rpn_regr: 0.0222 - detector_cls: 0.0027 - detector_regr: 0.0030Exception: 'a' cannot be empty unless no samples are taken
#  170/1000 [====>.........................] - ETA: 2590s - rpn_cls: 0.0013 - rpn_regr: 0.0221 - detector_cls: 0.0026 - detector_regr: 0.0030Exception: 'a' cannot be empty unless no samples are taken
#  173/1000 [====>.........................] - ETA: 2588s - rpn_cls: 0.0013 - rpn_regr: 0.0224 - detector_cls: 0.0026 - detector_regr: 0.0030Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  175/1000 [====>.........................] - ETA: 2579s - rpn_cls: 0.0013 - rpn_regr: 0.0223 - detector_cls: 0.0026 - detector_regr: 0.0030Exception: 'a' cannot be empty unless no samples are taken
#  176/1000 [====>.........................] - ETA: 2571s - rpn_cls: 0.0013 - rpn_regr: 0.0222 - detector_cls: 0.0026 - detector_regr: 0.0029Exception: 'a' cannot be empty unless no samples are taken
#  178/1000 [====>.........................] - ETA: 2559s - rpn_cls: 0.0013 - rpn_regr: 0.0221 - detector_cls: 0.0025 - detector_regr: 0.0029Exception: 'a' cannot be empty unless no samples are taken
#  180/1000 [====>.........................] - ETA: 2551s - rpn_cls: 0.0013 - rpn_regr: 0.0220 - detector_cls: 0.0025 - detector_regr: 0.0030Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  182/1000 [====>.........................] - ETA: 2545s - rpn_cls: 0.0013 - rpn_regr: 0.0220 - detector_cls: 0.0025 - detector_regr: 0.0029Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  183/1000 [====>.........................] - ETA: 2549s - rpn_cls: 0.0013 - rpn_regr: 0.0219 - detector_cls: 0.0025 - detector_regr: 0.0029Exception: 'a' cannot be empty unless no samples are taken
#  185/1000 [====>.........................] - ETA: 2544s - rpn_cls: 0.0013 - rpn_regr: 0.0219 - detector_cls: 0.0025 - detector_regr: 0.0029Exception: 'a' cannot be empty unless no samples are taken
#  186/1000 [====>.........................] - ETA: 2540s - rpn_cls: 0.0013 - rpn_regr: 0.0220 - detector_cls: 0.0025 - detector_regr: 0.0029Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  191/1000 [====>.........................] - ETA: 2507s - rpn_cls: 0.0013 - rpn_regr: 0.0229 - detector_cls: 0.0025 - detector_regr: 0.0029Exception: 'a' cannot be empty unless no samples are taken
#  193/1000 [====>.........................] - ETA: 2497s - rpn_cls: 0.0013 - rpn_regr: 0.0233 - detector_cls: 0.0024 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
#  198/1000 [====>.........................] - ETA: 2460s - rpn_cls: 0.0013 - rpn_regr: 0.0231 - detector_cls: 0.0024 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
#  199/1000 [====>.........................] - ETA: 2463s - rpn_cls: 0.0013 - rpn_regr: 0.0232 - detector_cls: 0.0024 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
#  203/1000 [=====>........................] - ETA: 2432s - rpn_cls: 0.0018 - rpn_regr: 0.0235 - detector_cls: 0.0023 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  212/1000 [=====>........................] - ETA: 2398s - rpn_cls: 0.0024 - rpn_regr: 0.0249 - detector_cls: 0.0024 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  213/1000 [=====>........................] - ETA: 2396s - rpn_cls: 0.0023 - rpn_regr: 0.0249 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  214/1000 [=====>........................] - ETA: 2401s - rpn_cls: 0.0023 - rpn_regr: 0.0253 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  218/1000 [=====>........................] - ETA: 2380s - rpn_cls: 0.0027 - rpn_regr: 0.0257 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  219/1000 [=====>........................] - ETA: 2396s - rpn_cls: 0.0027 - rpn_regr: 0.0257 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  221/1000 [=====>........................] - ETA: 2385s - rpn_cls: 0.0028 - rpn_regr: 0.0257 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  225/1000 [=====>........................] - ETA: 2378s - rpn_cls: 0.0027 - rpn_regr: 0.0256 - detector_cls: 0.0022 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  228/1000 [=====>........................] - ETA: 2375s - rpn_cls: 0.0028 - rpn_regr: 0.0256 - detector_cls: 0.0023 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  230/1000 [=====>........................] - ETA: 2376s - rpn_cls: 0.0028 - rpn_regr: 0.0259 - detector_cls: 0.0022 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  231/1000 [=====>........................] - ETA: 2371s - rpn_cls: 0.0027 - rpn_regr: 0.0258 - detector_cls: 0.0022 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  232/1000 [=====>........................] - ETA: 2369s - rpn_cls: 0.0027 - rpn_regr: 0.0258 - detector_cls: 0.0022 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  237/1000 [======>.......................] - ETA: 2341s - rpn_cls: 0.0027 - rpn_regr: 0.0257 - detector_cls: 0.0022 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  239/1000 [======>.......................] - ETA: 2328s - rpn_cls: 0.0027 - rpn_regr: 0.0257 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  240/1000 [======>.......................] - ETA: 2339s - rpn_cls: 0.0027 - rpn_regr: 0.0257 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  241/1000 [======>.......................] - ETA: 2340s - rpn_cls: 0.0027 - rpn_regr: 0.0257 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  242/1000 [======>.......................] - ETA: 2345s - rpn_cls: 0.0026 - rpn_regr: 0.0256 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  243/1000 [======>.......................] - ETA: 2342s - rpn_cls: 0.0026 - rpn_regr: 0.0255 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  247/1000 [======>.......................] - ETA: 2330s - rpn_cls: 0.0026 - rpn_regr: 0.0257 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  248/1000 [======>.......................] - ETA: 2332s - rpn_cls: 0.0026 - rpn_regr: 0.0257 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  251/1000 [======>.......................] - ETA: 2327s - rpn_cls: 0.0026 - rpn_regr: 0.0258 - detector_cls: 0.0024 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
#  256/1000 [======>.......................] - ETA: 2291s - rpn_cls: 0.0025 - rpn_regr: 0.0257 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  257/1000 [======>.......................] - ETA: 2289s - rpn_cls: 0.0025 - rpn_regr: 0.0257 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  258/1000 [======>.......................] - ETA: 2284s - rpn_cls: 0.0025 - rpn_regr: 0.0257 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  260/1000 [======>.......................] - ETA: 2280s - rpn_cls: 0.0025 - rpn_regr: 0.0259 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  263/1000 [======>.......................] - ETA: 2266s - rpn_cls: 0.0025 - rpn_regr: 0.0258 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  266/1000 [======>.......................] - ETA: 2257s - rpn_cls: 0.0025 - rpn_regr: 0.0257 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  267/1000 [=======>......................] - ETA: 2268s - rpn_cls: 0.0025 - rpn_regr: 0.0258 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  268/1000 [=======>......................] - ETA: 2269s - rpn_cls: 0.0025 - rpn_regr: 0.0258 - detector_cls: 0.0023 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  269/1000 [=======>......................] - ETA: 2269s - rpn_cls: 0.0025 - rpn_regr: 0.0258 - detector_cls: 0.0023 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  270/1000 [=======>......................] - ETA: 2275s - rpn_cls: 0.0025 - rpn_regr: 0.0258 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  273/1000 [=======>......................] - ETA: 2265s - rpn_cls: 0.0024 - rpn_regr: 0.0258 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  275/1000 [=======>......................] - ETA: 2255s - rpn_cls: 0.0024 - rpn_regr: 0.0260 - detector_cls: 0.0025 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  283/1000 [=======>......................] - ETA: 2207s - rpn_cls: 0.0024 - rpn_regr: 0.0265 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  286/1000 [=======>......................] - ETA: 2190s - rpn_cls: 0.0024 - rpn_regr: 0.0266 - detector_cls: 0.0024 - detector_regr: 0.0026Exception: 'a' cannot be empty unless no samples are taken
#  287/1000 [=======>......................] - ETA: 2185s - rpn_cls: 0.0024 - rpn_regr: 0.0266 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  288/1000 [=======>......................] - ETA: 2188s - rpn_cls: 0.0024 - rpn_regr: 0.0266 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  290/1000 [=======>......................] - ETA: 2183s - rpn_cls: 0.0024 - rpn_regr: 0.0265 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  291/1000 [=======>......................] - ETA: 2183s - rpn_cls: 0.0024 - rpn_regr: 0.0265 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  294/1000 [=======>......................] - ETA: 2170s - rpn_cls: 0.0024 - rpn_regr: 0.0265 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  296/1000 [=======>......................] - ETA: 2164s - rpn_cls: 0.0024 - rpn_regr: 0.0264 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  301/1000 [========>.....................] - ETA: 2134s - rpn_cls: 0.0025 - rpn_regr: 0.0262 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  302/1000 [========>.....................] - ETA: 2136s - rpn_cls: 0.0024 - rpn_regr: 0.0261 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  304/1000 [========>.....................] - ETA: 2134s - rpn_cls: 0.0024 - rpn_regr: 0.0262 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  305/1000 [========>.....................] - ETA: 2135s - rpn_cls: 0.0024 - rpn_regr: 0.0262 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  306/1000 [========>.....................] - ETA: 2133s - rpn_cls: 0.0024 - rpn_regr: 0.0261 - detector_cls: 0.0024 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  308/1000 [========>.....................] - ETA: 2122s - rpn_cls: 0.0024 - rpn_regr: 0.0260 - detector_cls: 0.0023 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
# Exception: 'a' cannot be empty unless no samples are taken
#  316/1000 [========>.....................] - ETA: 2082s - rpn_cls: 0.0025 - rpn_regr: 0.0261 - detector_cls: 0.0027 - detector_regr: 0.0027Exception: 'a' cannot be empty unless no samples are taken
#  318/1000 [========>.....................] - ETA: 2078s - rpn_cls: 0.0025 - rpn_regr: 0.0262 - detector_cls: 0.0031 - detector_regr: 0.0028Exception: 'a' cannot be empty unless no samples are taken
#  320/1000 [========>.....................] - ETA: 2074s - rpn_cls: 0.0025 - rpn_regr: 0.0261 - detector_cls: 0.0031 - detector_regr: 0.0028

# %%
# !python test_frcnn.py -p test_files
